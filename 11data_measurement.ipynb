# %% [markdown]
# # Taking Measure of the Data - Complete Dataset
#
# Aus: Walker, Michael (2024): Python data cleaning cookbook. Prepare your data for analysis with pandas, NumPy, Matplotlib, scikit-learn and OpenAI. Second edition. Taking Measure of Your Data. Birmingham, UK: Packt Publishing Ltd (Expert insight). Online verfügbar unter https://learning.oreilly.com/library/view/-/9781803239873/?ar.

# %%
import pandas as pd
import numpy as np

# %%
# Import Data 
data = pd.read_csv('C:/Users/ChiaraVogt/Desktop/Masterarbeit/Ligue180-HotlineDemand-ViolenceAgainstWomenInBrazil/df_all.csv')
data.head(5)
# Out:
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_17216\514045541.py:2: DtypeWarning: Columns (21,22,23,26,42,43,44,47,53,57,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('C:/Users/ChiaraVogt/Desktop/Masterarbeit/Ligue180-HotlineDemand-ViolenceAgainstWomenInBrazil/df_all.csv')
#    Unnamed: 0                              hash     Data_de_cadastro  \
# 0           0  274c244387540554e7b56f056aae6cd6  2021-01-12 12:29:00
# 1           1  3f748d382c602ff275d6f87d4697a96c  2021-01-09 17:07:00
# 2           2  c6cc7ef10b7b9e9d0fba099b9e1b9029  2021-01-01 09:45:00
# 3           3  5deb4eb53c9cc94621cb3128c3b5f5e2  2021-01-14 15:07:00
# 4           4  09cec588d52b441b5b9a37f6b0650df6  2021-01-08 23:56:00
#
#   Canal_de_atendimento Denúncia_emergencial       Denunciante  \
# 0           TELEFÔNICO                  NÃO           ANÔNIMO
# 1           TELEFÔNICO                  NÃO  A PRÓPRIA VÍTIMA
# 2           TELEFÔNICO                  NÃO           ANÔNIMO
# 3           TELEFÔNICO                  NÃO  A PRÓPRIA VÍTIMA
# 4           TELEFÔNICO                  NÃO           ANÔNIMO
#
#                       Cenário_da_violação    País  UF         Município  ...  \
# 0  CASA ONDE RESIDE A VÍTIMA E O SUSPEITO  BRASIL  AM            MANAUS  ...
# 1                          CASA DA VÍTIMA  BRASIL  AM       ITACOATIARA  ...
# 2  CASA ONDE RESIDE A VÍTIMA E O SUSPEITO  BRASIL  PB     SERRA REDONDA  ...
# 3             LOCAL DE TRABALHO DA VÍTIMA  BRASIL  AM            MANAUS  ...
# 4    TRANSPORTE MONITORADO POR APLICATIVO  BRASIL  BA  FEIRA DE SANTANA  ...
#
#    Grau_de_instrução_do_suspeito        Religião_do_suspeito  \
# 0                            N/D                         N/D
# 1                            N/D                         N/D
# 2  ENSINO FUNDAMENTAL INCOMPLETO  CATÓLICA APOSTÓLICA ROMANA
# 3                            N/D                         N/D
# 4                            N/D                         N/D
#
#    Raça_Cor_do_suspeito Suspeito_Etnia Faixa_de_renda_do_suspeito  \
# 0                   N/D            N/D                        N/D
# 1                   N/D            N/D                        N/D
# 2                BRANCA            N/D                   ATÉ 1 SM
# 3                 PARDA            N/D                        N/D
# 4                   N/D            N/D                        N/D
#
#   Vínculo_Órgão_PJ_do_suspeito sl_suspeito_ramo suspeito_especificacao_etnia  \
# 0                          NaN              N/D                          N/D
# 1                          NaN              N/D                          N/D
# 2                          NaN              N/D                          N/D
# 3                          NaN              N/D                          N/D
# 4                          NaN              N/D                          N/D
#
#   vitima_especificacao_etnia                               violacao
# 0                        N/D  INTEGRIDADE>PSÍQUICA>TORTURA PSÍQUICA
# 1                        N/D  INTEGRIDADE>PSÍQUICA>AMEAÇA ou COAÇÃO
# 2                        N/D         INTEGRIDADE>PSÍQUICA>EXPOSIÇÃO
# 3                        N/D   INTEGRIDADE>PSÍQUICA>CONSTRANGIMENTO
# 4                        N/D   INTEGRIDADE>PSÍQUICA>CONSTRANGIMENTO
#
# [5 rows x 63 columns]

# %%
# Columns with Mixed Datatype
print(data.columns[[21, 22, 23, 26, 42, 43, 44, 47, 53, 57, 58]])
# Out:
# Index(['sl_vitima_naturalidade', 'sl_vitima_naturalizado_uf',
#        'sl_vitima_naturalizado_municipio',
#        'Deficiência_relacionada_a_doença_rara', 'sl_suspeito_naturalidade',
#        'sl_suspeito_naturalizado_uf', 'sl_suspeito_naturalizado_municipio',
#        'Deficiência_relacionada_a_doença_rara_suspeito',
#        'Grau_de_instrução_do_suspeito', 'Faixa_de_renda_do_suspeito',
#        'Vínculo_Órgão_PJ_do_suspeito'],
#       dtype='object')

# %%
# Size of Dataset
data.shape
# Out:
# (1541113, 63)

# %%
# Columns and Null-Value
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1541113 entries, 0 to 1541112
# Data columns (total 63 columns):
#  #   Column                                          Non-Null Count    Dtype
# ---  ------                                          --------------    -----
#  0   Unnamed: 0                                      1541113 non-null  int64
#  1   hash                                            1541113 non-null  object
#  2   Data_de_cadastro                                1541113 non-null  object
#  3   Canal_de_atendimento                            1541055 non-null  object
#  4   Denúncia_emergencial                            1540943 non-null  object
#  5   Denunciante                                     1540974 non-null  object
#  6   Cenário_da_violação                             1539397 non-null  object
#  7   País                                            1540787 non-null  object
#  8   UF                                              1539962 non-null  object
#  9   Município                                       1539250 non-null  object
#  10  Frequência                                      1538526 non-null  object
#  11  Início_das_violações                            1538021 non-null  object
#  12  sl_quantidade_vitimas                           1541113 non-null  int64
#  13  Grupo_vulnerável                                1541113 non-null  object
#  14  Motivação                                       1185535 non-null  object
#  15  Relação_vítima_suspeito                         1540999 non-null  object
#  16  sl_vitima_cadastro                              1541103 non-null  object
#  17  Gênero_da_vítima                                1540951 non-null  object
#  18  Orientação_sexual_da_vítima                     1537669 non-null  object
#  19  Faixa_etária_da_vítima                          1509701 non-null  object
#  20  Nacionalidade_da_vítima                         1540518 non-null  object
#  21  sl_vitima_naturalidade                          516542 non-null   object
#  22  sl_vitima_naturalizado_uf                       495596 non-null   object
#  23  sl_vitima_naturalizado_municipio                448208 non-null   object
#  24  Deficiência_da_vítima                           823019 non-null   object
#  25  Doença_rara_da_vítima                           1540101 non-null  object
#  26  Deficiência_relacionada_a_doença_rara           199521 non-null   object
#  27  Vítima_preso_a                                  1537385 non-null  object
#  28  País_da_vítima                                  1541111 non-null  object
#  29  UF_da_vítima                                    1540009 non-null  object
#  30  Município_da_vítima                             1539154 non-null  object
#  31  Profissão_da_vítima                             974396 non-null   object
#  32  Grau_de_instrução_da_vítima                     1102954 non-null  object
#  33  Religião_da_vítima                              714080 non-null   object
#  34  Raça_Cor_da_vítima                              1531834 non-null  object
#  35  Etnia_da_vítima                                 692036 non-null   object
#  36  Faixa_de_renda_da_vítima                        954636 non-null   object
#  37  Natureza_Jurídica_do_Suspeito                   1541113 non-null  object
#  38  Gênero_do_suspeito                              1484434 non-null  object
#  39  Orientação_sexual_do_suspeito                   1472870 non-null  object
#  40  Faixa_etária_do_suspeito                        1424784 non-null  object
#  41  Suspeito_nacionalidade                          1539679 non-null  object
#  42  sl_suspeito_naturalidade                        454990 non-null   object
#  43  sl_suspeito_naturalizado_uf                     431995 non-null   object
#  44  sl_suspeito_naturalizado_municipio              350012 non-null   object
#  45  Deficiência_do_suspeito                         838156 non-null   object
#  46  Doença_rara_do_suspeito                         1485477 non-null  object
#  47  Deficiência_relacionada_a_doença_rara_suspeito  681684 non-null   object
#  48  Suspeito_preso                                  1423981 non-null  object
#  49  País_do_suspeito                                1540995 non-null  object
#  50  UF_do_suspeito                                  1538749 non-null  object
#  51  sl_suspeito_municipio                           1537082 non-null  object
#  52  Profissão_do_suspeito                           1354649 non-null  object
#  53  Grau_de_instrução_do_suspeito                   681711 non-null   object
#  54  Religião_do_suspeito                            708112 non-null   object
#  55  Raça_Cor_do_suspeito                            1263971 non-null  object
#  56  Suspeito_Etnia                                  698304 non-null   object
#  57  Faixa_de_renda_do_suspeito                      681693 non-null   object
#  58  Vínculo_Órgão_PJ_do_suspeito                    2722 non-null     object
#  59  sl_suspeito_ramo                                724398 non-null   object
#  60  suspeito_especificacao_etnia                    692538 non-null   object
#  61  vitima_especificacao_etnia                      706861 non-null   object
#  62  violacao                                        1458432 non-null  object
# dtypes: int64(2), object(61)
# memory usage: 740.7+ MB

# %%
data[data.select_dtypes(['object']).columns] = \
  data.select_dtypes(['object']). \
  transform(lambda x: x.astype('category'))

# %%
# Explore by categories
