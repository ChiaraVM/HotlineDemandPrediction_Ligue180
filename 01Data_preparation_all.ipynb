# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Preparation of the Time Prediction Analysis Data

# %%
# Load Timestamp of Dataset
path = "C:/Users/ChiaraVogt/Desktop/Masterarbeit/DatenLigue180/"
d2014 = pd.read_csv(path + "ligue180-2014.csv", encoding='utf-8-sig', delimiter=';')
d2015 = pd.read_csv(path + "ligue180-2015.csv", encoding='utf-8-sig', delimiter=';')
d2016 = pd.read_csv(path + "ligue180-2016.csv", encoding='utf-8-sig', delimiter=';')
d2017 = pd.read_csv(path + "ligue180-2017.csv", encoding='utf-8-sig', delimiter=';')
d2018 = pd.read_csv(path + "ligue180-2018.csv", encoding='utf-8-sig', delimiter=';')
d2018_2 = pd.read_csv(path + "ligue180-nov-2018.csv", encoding='utf-8-sig', delimiter=';')
d2019 = pd.read_csv(path + "ligue180-2019.csv", encoding='utf-8-sig', delimiter=';')
d2020 = pd.read_csv(path + "ligue180-primeiro-semestre-2020.csv", encoding='utf-8-sig', delimiter=';')
d2020_2 = pd.read_csv(path + "ligue180-segundo-semestre-2020.csv", encoding='utf-8-sig', delimiter=';')
d2021 = pd.read_csv(path + "ligue180-primeiro-semestre-2021.csv", encoding='utf-8-sig', delimiter=';')
d2021_2 = pd.read_csv(path + "ligue180-segundo-semestre-2021.csv", encoding='utf-8-sig', delimiter=';')
d2022 = pd.read_csv(path + "ligue180-primeiro-semestre-2022.csv", encoding='utf-8-sig', delimiter=';')
d2022_2 = pd.read_csv(path + "ligue180-segundo-semestre-2022.csv", encoding='utf-8-sig', delimiter=';')
d2023 = pd.read_csv(path + "ligue180-primeiro-semestre-2023.csv", encoding='utf-8-sig', delimiter=';')
d2023_2 = pd.read_csv(path + "ligue180-segundo-semestre-2023.csv", encoding='utf-8-sig', delimiter=';')
# Out:
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\3817827875.py:5: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2016 = pd.read_csv(path + "ligue180-2016.csv", encoding='utf-8-sig', delimiter=';')
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\3817827875.py:15: DtypeWarning: Columns (20,21,22,41,42,43,46,52,56,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2022_2 = pd.read_csv(path + "ligue180-segundo-semestre-2022.csv", encoding='utf-8-sig', delimiter=';')
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\3817827875.py:16: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2023 = pd.read_csv(path + "ligue180-primeiro-semestre-2023.csv", encoding='utf-8-sig', delimiter=';')

# %%
# Timestamp angleichen
d2014['data_atendimento'] = pd.to_datetime(d2014['data_atendimento'], dayfirst = True)
d2015['data_atendimento'] = pd.to_datetime(d2015['data_atendimento'])
d2016['data_atendimento'] = pd.to_datetime(d2016['data_atendimento'], dayfirst = True)
d2017['data_atendimento'] = pd.to_datetime(d2017['data_atendimento'])
d2018['data_atendimento'] = pd.to_datetime(d2018['data_atendimento'])
d2018_2['data_atendimento'] = pd.to_datetime(d2018_2['data_atendimento'])
d2019['data_atendimento'] = pd.to_datetime(d2019['data_atendimento'])
d2020['Data_da_denúncia'] = pd.to_datetime(d2020['Data_da_denúncia'], dayfirst = True)
d2020_2['Data de cadastro'] = pd.to_datetime(d2020_2['Data de cadastro'], dayfirst = True)
d2021['Data de cadastro'] = pd.to_datetime(d2021['Data de cadastro'], dayfirst = True)
d2021_2['Data de cadastro'] = pd.to_datetime(d2021_2['Data de cadastro'], dayfirst = True)
d2022['Data de cadastro'] = pd.to_datetime(d2022['Data de cadastro'], dayfirst = True)
d2022_2['Data_de_cadastro'] = pd.to_datetime(d2022_2['Data_de_cadastro'], dayfirst = True)
d2023['Data_de_cadastro'] = pd.to_datetime(d2023['Data_de_cadastro'], dayfirst = True)
d2023_2['Data_de_cadastro'] = pd.to_datetime(d2023_2['Data_de_cadastro'], dayfirst = True)
# Out:
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\3632634151.py:2: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S.%f format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   d2014['data_atendimento'] = pd.to_datetime(d2014['data_atendimento'], dayfirst = True)
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\3632634151.py:4: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S.%f format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   d2016['data_atendimento'] = pd.to_datetime(d2016['data_atendimento'], dayfirst = True)
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\3632634151.py:16: UserWarning: Parsing dates in %Y-%m-%d %H:%M:%S.%f format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   d2023_2['Data_de_cadastro'] = pd.to_datetime(d2023_2['Data_de_cadastro'], dayfirst = True)

# %%
# Angeleichen der Spaltennamen für 2020 bis 2023

# 2020
d2020 = d2020.rename(columns={'hash_par_vitima_suspeito':'hash', 
                              'Data_da_denúncia': 'Data_de_cadastro', 
                              'Canal_de_atendimento':'Canal_de_atendimento', 
                              'Denúncia_Emergencial':'Denúncia_emergencial', 
                              'motivacoes': 'Motivação', 
                              'Relação_Suspeito_x_Vítima': 'Relação_vítima_suspeito', 
                              'orientacao_sexual': 'Orientação_sexual_da_vítima', 
                              'idade_vitima': 'Faixa_etária_da_vítima', 
                              'deficiencia_vitima':'Deficiência_da_vítima', 
                              'Nacionalidade_da_vítima': 'Nacionalidade_da_vítima', 
                              'País_de_orígem_da_vítima': 'País_da_vítima', 
                              'Grau_instrução_da_vítima': 'Grau_de_instrução_da_vítima', 
                              'Raça_cor_da_vítima': 'Raça_Cor_da_vítima', 
                              'idade_suspeito': 'Faixa_etária_do_suspeito', 
                              'Nacionalidade_do_suspeito': 'Suspeito_nacionalidade',
                              'deficiencia_suspeito': 'Deficiência_do_suspeito', 
                              'País_de_orígem_do_suspeito': 'País_do_suspeito', 
                              'Raça_cor_do_suspeito': 'Raça_Cor_do_suspeito', 
                              'Etnia_do_suspeito': 'Suspeito_Etnia', 
                              'violacoes': 'violacao'})
#
# 2020_2
d2020_2 = d2020_2.rename(columns={'Data de cadastro': 'Data_de_cadastro', 'Canal de atendimento': 'Canal_de_atendimento', 
                              'Denúncia emergencial':'Denúncia_emergencial', 'Cenário da violação': 'Cenário_da_violação', 
                               'Início das violações': 'Início_das_violações', 'Grupo vulnerável': 'Grupo_vulnerável', 
                              'Relação vítima-suspeito': 'Relação_vítima_suspeito', 'Gênero da vítima': 'Gênero_da_vítima', 
                                  'Orientação sexual da vítima': 'Orientação_sexual_da_vítima', 'Faixa etária da vítima': 
                                  'Faixa_etária_da_vítima', 'Nacionalidade da vítima': 'Nacionalidade_da_vítima', 
                                  'Deficiência da vítima':'Deficiência_da_vítima', 'Doença rara da vítima': 'Doença_rara_da_vítima',
                                  'Deficiência relacionada a doença rara ?': 'Deficiência_relacionada_a_doença_rara', 
                                  'Vítima preso(a)': 'Vítima_preso_a', 'País da vítima': 'País_da_vítima', 'UF da vítima': 'UF_da_vítima',
                                  'Município  da vítima': 'Município_da_vítima', 'Profissão da vítima': 'Profissão_da_vítima', 
                                  'Grau de instrução da vítima': 'Grau_de_instrução_da_vítima', 'Religião da vítima': 'Religião_da_vítima', 
                                  'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima', 
                                  'Faixa de renda da vítima': 'Faixa_de_renda_da_vítima', 'Natureza Jurídica do Suspeito': 'Natureza_Jurídica_do_Suspeito',
                                  'Gênero do suspeito': 'Gênero_do_suspeito', 'Orientação sexual do suspeito': 'Orientação_sexual_do_suspeito',
                                  'Faixa etária do suspeito': 'Faixa_etária_do_suspeito', 'Suspeito nacionalidade': 'Suspeito_nacionalidade',
                                  'Deficiência do suspeito': 'Deficiência_do_suspeito', 'Doença rara do suspeito': 'Doença_rara_do_suspeito',
                                  'Deficiência relacionada a doença rara (suspeito) ?': 'Deficiência_relacionada_a_doença_rara_suspeito', 
                                  'Suspeito preso': 'Suspeito_preso', 'País do suspeito': 'País_do_suspeito', 'UF do suspeito': 'UF_do_suspeito',
                                  'Profissão do suspeito': 'Profissão_do_suspeito', 'Grau de instrução do suspeito': 'Grau_de_instrução_do_suspeito',
                                  'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito', 
                                  'Suspeito Etnia': 'Suspeito_Etnia', 'Faixa de renda do suspeito': 'Faixa_de_renda_do_suspeito', 
                                  'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})

# 2021
d2021 = d2021.rename(columns={'Data de cadastro': 'Data_de_cadastro', 'Canal de atendimento': 'Canal_de_atendimento', 
                              'Denúncia emergencial':'Denúncia_emergencial', 'Cenário da violação': 'Cenário_da_violação', 
                               'Início das violações': 'Início_das_violações', 'Grupo vulnerável': 'Grupo_vulnerável', 
                              'Relação vítima-suspeito': 'Relação_vítima_suspeito', 'Gênero da vítima': 'Gênero_da_vítima', 
                                  'Orientação sexual da vítima': 'Orientação_sexual_da_vítima', 'Faixa etária da vítima': 
                                  'Faixa_etária_da_vítima', 'Nacionalidade da vítima': 'Nacionalidade_da_vítima', 
                                  'Deficiência da vítima':'Deficiência_da_vítima', 'Doença rara da vítima': 'Doença_rara_da_vítima',
                                  'Deficiência relacionada a doença rara ?': 'Deficiência_relacionada_a_doença_rara', 
                                  'Vítima preso(a)': 'Vítima_preso_a', 'País da vítima': 'País_da_vítima', 'UF da vítima': 'UF_da_vítima',
                                  'Município  da vítima': 'Município_da_vítima', 'Profissão da vítima': 'Profissão_da_vítima', 
                                  'Grau de instrução da vítima': 'Grau_de_instrução_da_vítima', 'Religião da vítima': 'Religião_da_vítima', 
                                  'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima', 
                                  'Faixa de renda da vítima': 'Faixa_de_renda_da_vítima', 'Natureza Jurídica do Suspeito': 'Natureza_Jurídica_do_Suspeito',
                                  'Gênero do suspeito': 'Gênero_do_suspeito', 'Orientação sexual do suspeito': 'Orientação_sexual_do_suspeito',
                                  'Faixa etária do suspeito': 'Faixa_etária_do_suspeito', 'Suspeito nacionalidade': 'Suspeito_nacionalidade',
                                  'Deficiência do suspeito': 'Deficiência_do_suspeito', 'Doença rara do suspeito': 'Doença_rara_do_suspeito',
                                  'Deficiência relacionada a doença rara (suspeito) ?': 'Deficiência_relacionada_a_doença_rara_suspeito', 
                                  'Suspeito preso': 'Suspeito_preso', 'País do suspeito': 'País_do_suspeito', 'UF do suspeito': 'UF_do_suspeito',
                                  'Profissão do suspeito': 'Profissão_do_suspeito', 'Grau de instrução do suspeito': 'Grau_de_instrução_do_suspeito',
                                  'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito', 
                                  'Suspeito Etnia': 'Suspeito_Etnia', 'Faixa de renda do suspeito': 'Faixa_de_renda_do_suspeito', 
                                  'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})

# 2021_2
d2021_2 = d2021_2.rename(columns={'Data de cadastro': 'Data_de_cadastro', 'Canal de atendimento': 'Canal_de_atendimento',
                                  'Denúncia emergencial':'Denúncia_emergencial', 'Cenário da violação': 'Cenário_da_violação', 
                                  'Início das violações': 'Início_das_violações', 'Grupo vulnerável': 'Grupo_vulnerável', 
                                  'Relação vítima-suspeito': 'Relação_vítima_suspeito', 'Gênero da vítima': 'Gênero_da_vítima', 
                                  'Orientação sexual da vítima': 'Orientação_sexual_da_vítima', 'Faixa etária da vítima': 
                                  'Faixa_etária_da_vítima', 'Nacionalidade da vítima': 'Nacionalidade_da_vítima', 
                                  'Deficiência da vítima':'Deficiência_da_vítima', 'Doença rara da vítima': 'Doença_rara_da_vítima',
                                  'Deficiência relacionada a doença rara ?': 'Deficiência_relacionada_a_doença_rara', 
                                  'Vítima preso(a)': 'Vítima_preso_a', 'País da vítima': 'País_da_vítima', 'UF da vítima': 'UF_da_vítima',
                                  'Município  da vítima': 'Município_da_vítima', 'Profissão da vítima': 'Profissão_da_vítima', 
                                  'Grau de instrução da vítima': 'Grau_de_instrução_da_vítima', 'Religião da vítima': 'Religião_da_vítima', 
                                  'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima', 
                                  'Faixa de renda da vítima': 'Faixa_de_renda_da_vítima', 'Natureza Jurídica do Suspeito': 'Natureza_Jurídica_do_Suspeito',
                                  'Gênero do suspeito': 'Gênero_do_suspeito', 'Orientação sexual do suspeito': 'Orientação_sexual_do_suspeito',
                                  'Faixa etária do suspeito': 'Faixa_etária_do_suspeito', 'Suspeito nacionalidade': 'Suspeito_nacionalidade',
                                  'Deficiência do suspeito': 'Deficiência_do_suspeito', 'Doença rara do suspeito': 'Doença_rara_do_suspeito',
                                  'Deficiência relacionada a doença rara (suspeito) ?': 'Deficiência_relacionada_a_doença_rara_suspeito', 
                                  'Suspeito preso': 'Suspeito_preso', 'País do suspeito': 'País_do_suspeito', 'UF do suspeito': 'UF_do_suspeito',
                                  'Profissão do suspeito': 'Profissão_do_suspeito', 'Grau de instrução do suspeito': 'Grau_de_instrução_do_suspeito',
                                  'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito', 
                                  'Suspeito Etnia': 'Suspeito_Etnia', 'Faixa de renda do suspeito': 'Faixa_de_renda_do_suspeito', 
                                  'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})

# 2022
d2022 = d2022.rename(columns={'Data de cadastro': 'Data_de_cadastro', 'Canal de atendimento': 'Canal_de_atendimento',
                                  'Denúncia emergencial':'Denúncia_emergencial', 'Cenário da violação': 'Cenário_da_violação', 
                                  'Início das violações': 'Início_das_violações', 'Grupo vulnerável': 'Grupo_vulnerável', 
                                  'Relação vítima-suspeito': 'Relação_vítima_suspeito', 'Gênero da vítima': 'Gênero_da_vítima', 
                                  'Orientação sexual da vítima': 'Orientação_sexual_da_vítima', 'Faixa etária da vítima': 
                                  'Faixa_etária_da_vítima', 'Nacionalidade da vítima': 'Nacionalidade_da_vítima', 
                                  'Deficiência da vítima':'Deficiência_da_vítima', 'Doença rara da vítima': 'Doença_rara_da_vítima',
                                  'Deficiência relacionada a doença rara ?': 'Deficiência_relacionada_a_doença_rara', 
                                  'Vítima preso(a)': 'Vítima_preso_a', 'País da vítima': 'País_da_vítima', 'UF da vítima': 'UF_da_vítima',
                                  'Município  da vítima': 'Município_da_vítima', 'Profissão da vítima': 'Profissão_da_vítima', 
                                  'Grau de instrução da vítima': 'Grau_de_instrução_da_vítima', 'Religião da vítima': 'Religião_da_vítima', 
                                  'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima', 
                                  'Faixa de renda da vítima': 'Faixa_de_renda_da_vítima', 'Natureza Jurídica do Suspeito': 'Natureza_Jurídica_do_Suspeito',
                                  'Gênero do suspeito': 'Gênero_do_suspeito', 'Orientação sexual do suspeito': 'Orientação_sexual_do_suspeito',
                                  'Faixa etária do suspeito': 'Faixa_etária_do_suspeito', 'Suspeito nacionalidade': 'Suspeito_nacionalidade',
                                  'Deficiência do suspeito': 'Deficiência_do_suspeito', 'Doença rara do suspeito': 'Doença_rara_do_suspeito',
                                  'Deficiência relacionada a doença rara (suspeito) ?': 'Deficiência_relacionada_a_doença_rara_suspeito', 
                                  'Suspeito preso': 'Suspeito_preso', 'País do suspeito': 'País_do_suspeito', 'UF do suspeito': 'UF_do_suspeito',
                                  'Profissão do suspeito': 'Profissão_do_suspeito', 'Grau de instrução do suspeito': 'Grau_de_instrução_do_suspeito',
                                  'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito', 
                                  'Suspeito Etnia': 'Suspeito_Etnia', 'Faixa de renda do suspeito': 'Faixa_de_renda_do_suspeito', 
                                  'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\C'
# <>:45: SyntaxWarning: invalid escape sequence '\C'
# <>:47: SyntaxWarning: invalid escape sequence '\P'
# <>:61: SyntaxWarning: invalid escape sequence '\C'
# <>:69: SyntaxWarning: invalid escape sequence '\C'
# <>:71: SyntaxWarning: invalid escape sequence '\P'
# <>:85: SyntaxWarning: invalid escape sequence '\C'
# <>:93: SyntaxWarning: invalid escape sequence '\C'
# <>:95: SyntaxWarning: invalid escape sequence '\P'
# <>:109: SyntaxWarning: invalid escape sequence '\C'
# <>:117: SyntaxWarning: invalid escape sequence '\C'
# <>:119: SyntaxWarning: invalid escape sequence '\P'
# <>:37: SyntaxWarning: invalid escape sequence '\C'
# <>:45: SyntaxWarning: invalid escape sequence '\C'
# <>:47: SyntaxWarning: invalid escape sequence '\P'
# <>:61: SyntaxWarning: invalid escape sequence '\C'
# <>:69: SyntaxWarning: invalid escape sequence '\C'
# <>:71: SyntaxWarning: invalid escape sequence '\P'
# <>:85: SyntaxWarning: invalid escape sequence '\C'
# <>:93: SyntaxWarning: invalid escape sequence '\C'
# <>:95: SyntaxWarning: invalid escape sequence '\P'
# <>:109: SyntaxWarning: invalid escape sequence '\C'
# <>:117: SyntaxWarning: invalid escape sequence '\C'
# <>:119: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:37: SyntaxWarning: invalid escape sequence '\C'
#   'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:45: SyntaxWarning: invalid escape sequence '\C'
#   'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:47: SyntaxWarning: invalid escape sequence '\P'
#   'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:61: SyntaxWarning: invalid escape sequence '\C'
#   'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:69: SyntaxWarning: invalid escape sequence '\C'
#   'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:71: SyntaxWarning: invalid escape sequence '\P'
#   'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:85: SyntaxWarning: invalid escape sequence '\C'
#   'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:93: SyntaxWarning: invalid escape sequence '\C'
#   'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:95: SyntaxWarning: invalid escape sequence '\P'
#   'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:109: SyntaxWarning: invalid escape sequence '\C'
#   'Raça\Cor da vítima': 'Raça_Cor_da_vítima', 'Etnia da vítima': 'Etnia_da_vítima',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:117: SyntaxWarning: invalid escape sequence '\C'
#   'Religião do suspeito': 'Religião_do_suspeito', 'Raça\Cor do suspeito': 'Raça_Cor_do_suspeito',
# C:\Users\ChiaraVogt\AppData\Local\Temp\ipykernel_19852\1333662984.py:119: SyntaxWarning: invalid escape sequence '\P'
#   'Vínculo Órgão\PJ do suspeito': 'Vínculo_Órgão_PJ_do_suspeito'})

# %%
# Jahre zu einem Datensatz verbinden
d2020 = pd.concat([d2020, d2020_2], ignore_index = True)
d2021 = pd.concat([d2021, d2021_2], ignore_index = True)
d2022 = pd.concat([d2022, d2022_2], ignore_index = True)
d2023 = pd.concat([d2023, d2023_2], ignore_index = True)

# %%
# Daten in ein dictionary packen
dict_all_2020 = {

    2020: d2020,
    2021: d2021,
    2022: d2022,
    2023: d2023

}

# Alle Jahre in ein Dataframe packen
data_all_2020 = pd.concat([dict_all_2020[2020], dict_all_2020[2021], dict_all_2020[2022], dict_all_2020[2023]], ignore_index= True)

# Testdatensatz bauen
df_test = pd.concat([dict_all_2020[2020].loc[0:50].copy(), dict_all_2020[2021].loc[0:50].copy(), dict_all_2020[2022].loc[0:50].copy(), dict_all_2020[2023].loc[0:50].copy()], ignore_index= True)

# %%
data_all_2020.columns
# Out:
# Index(['hash', 'Data_de_cadastro', 'Denunciante', 'relacao_demandante_vitima',
#        'Canal_de_atendimento', 'País_da_vítima', 'UF', 'Estado', 'Município',
#        'Cenário_da_violação', 'Grupo_vulnerável', 'Gênero_da_vítima',
#        'Faixa_etária_da_vítima', 'Grau_de_instrução_da_vítima',
#        'Faixa_de_renda_da_vítima', 'Raça_Cor_da_vítima',
#        'Deficiência_da_vítima', 'Gênero_do_suspeito',
#        'Faixa_etária_do_suspeito', 'Grau_instrução_do_suspeito',
#        'Faixa_de_renda_do_suspeito', 'Raça_Cor_do_suspeito',
#        'Deficiência_do_suspeito', 'Relação_vítima_suspeito',
#        'Denúncia_emergencial', 'Nacionalidade_da_vítima',
#        'Suspeito_nacionalidade', 'País_do_suspeito', 'Etnia_da_vítima',
#        'Suspeito_Etnia', 'violacao', 'Motivação', 'agravantes',
#        'Orientação_sexual_da_vítima', 'País', 'Frequência',
#        'Início_das_violações', 'sl_quantidade_vitimas', 'sl_vitima_cadastro',
#        'sl_vitima_naturalidade', 'sl_vitima_naturalizado_uf',
#        'sl_vitima_naturalizado_municipio', 'Doença_rara_da_vítima',
#        'Deficiência_relacionada_a_doença_rara', 'Vítima_preso_a',
#        'UF_da_vítima', 'Município_da_vítima', 'Profissão_da_vítima',
#        'Religião_da_vítima', 'Natureza_Jurídica_do_Suspeito',
#        'Orientação_sexual_do_suspeito', 'sl_suspeito_naturalidade',
#        'sl_suspeito_naturalizado_uf', 'sl_suspeito_naturalizado_municipio',
#        'Doença_rara_do_suspeito',
#        'Deficiência_relacionada_a_doença_rara_suspeito', 'Suspeito_preso',
#        'UF_do_suspeito', 'sl_suspeito_municipio', 'Profissão_do_suspeito',
#        'Grau_de_instrução_do_suspeito', 'Religião_do_suspeito',
#        'Vínculo_Órgão_PJ_do_suspeito', 'sl_suspeito_ramo',
#        'suspeito_especificacao_etnia', 'vitima_especificacao_etnia'],
#       dtype='object')

# %%
data_all_2020.to_csv('data_all_2020.csv', index=True)
